# %% [markdown]
# **Name: Kshitij Amitkumar Mondal<br>
# Roll No: TCOD-73<br>
# Class: TE-D<br>
# Batch: T12**

# %% [markdown]
# # Assignment No: 7
# Title of the Assignment:
# 1. Extract Sample document and apply following document preprocessing methods:
# Tokenization, POS Tagging, stop words removal, Stemming and Lemmatization.
# 2. Create representation of document by calculating Term Frequency and Inverse Document
# Frequency.

# %% [markdown]
# # Part 1

# %% [markdown]
# Download the required packages

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# Initialize the text

# %%
text= "Tokenization is the first step in text analytics. The process of breaking down a text paragraph into smaller chunks such as words or sentences is called Tokenization."

# %% [markdown]
# Perform Tokenization

# %%
#Sentence Tokenization
from nltk.tokenize import sent_tokenize
tokenized_text= sent_tokenize(text)
print(tokenized_text)
# Out:
# ['Tokenization is the first step in text analytics.', 'The process of breaking down a text paragraph into smaller chunks such as words or sentences is called Tokenization.']

# %%
#Word Tokenization
from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(text)
print(tokenized_word)
# Out:
# ['Tokenization', 'is', 'the', 'first', 'step', 'in', 'text', 'analytics', '.', 'The', 'process', 'of', 'breaking', 'down', 'a', 'text', 'paragraph', 'into', 'smaller', 'chunks', 'such', 'as', 'words', 'or', 'sentences', 'is', 'called', 'Tokenization', '.']

# %% [markdown]
# Removing Punctuations and Stop Word

# %%
#print stop words of English
from nltk.corpus import stopwords
stop_words=set(stopwords.words("english"))
print(stop_words)
# Out:
# {'couldn', "that'll", 'you', 'mustn', 'some', 'should', 'where', 'didn', 'm', 'haven', 'before', 'during', 'wouldn', 'hadn', 'that', 'a', 'against', 'me', 'when', 'down', 'has', 'all', 'both', 'her', 'weren', "she's", 'of', 'my', "mightn't", 'not', 'being', 'herself', 'to', 'each', 'into', 'in', 'more', "she'd", 'doing', 'i', 'if', "you'd", 'for', 'doesn', 'yours', "it'd", 'but', 'ma', "needn't", 'over', 'can', "aren't", 'then', 'their', 'its', "she'll", 'hasn', "we've", 'only', 'been', 'itself', 'll', "shan't", "they're", 'am', "we're", 'shouldn', 'does', "i've", 'whom', 'by', "couldn't", 'yourself', "you've", "didn't", "mustn't", 'with', 'as', 'hers', "they'd", 'above', "i'm", "haven't", 'just', 'yourselves', 'any', "it'll", 'wasn', 'why', 'same', 'about', 'on', 'have', 'other', 'at', 'himself', 'or', "i'll", 'until', "they'll", 'than', 've', "shouldn't", "don't", 'an', 'she', 'themselves', 'while', 'we', 's', 'now', 'so', 'ours', 'through', 'his', 't', 'it', "doesn't", 'off', "wasn't", 'ourselves', 'nor', 'these', 'mightn', "he'll", 'because', "it's", "should've", 'don', 'how', 'your', "he's", 'from', 'up', 'most', 'too', 'again', "we'll", 'did', 'be', 'is', "won't", 'further', "you're", "hasn't", 'o', "i'd", 'between', "you'll", 'very', 'below', 'own', 'were', 'once', 'what', 'no', 'out', 'had', 'those', 'do', 'this', "wouldn't", 'he', 'here', 'which', 'shan', 're', 'myself', 'the', "they've", 'having', 'and', 'ain', 'aren', "hadn't", "he'd", 'they', 'needn', 'will', 'won', 'theirs', 'there', 'd', 'after', 'was', 'y', 'isn', "we'd", 'our', 'few', 'who', 'under', 'such', 'him', 'are', 'them', "isn't", "weren't"}

# %%
import re
text= "How to remove stop words with NLTK library in Python?"
text= re.sub('[^a-zA-Z]', ' ',text)
tokens = word_tokenize(text.lower())
filtered_text=[]
for w in tokens:
  if w not in stop_words:
    filtered_text.append(w)
print("Tokenized Sentence:",tokens)
print("Filterd Sentence:",filtered_text)
# Out:
# Tokenized Sentence: ['how', 'to', 'remove', 'stop', 'words', 'with', 'nltk', 'library', 'in', 'python']
# Filterd Sentence: ['remove', 'stop', 'words', 'nltk', 'library', 'python']

# %% [markdown]
# Perform Stemming

# %%
from nltk.stem import PorterStemmer
e_words= ["wait", "waiting", "waited", "waits"]
ps =PorterStemmer()
for w in e_words:
  rootWord=ps.stem(w)
print(rootWord)
# Out:
# wait

# %% [markdown]
# Perform Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
text = "studies studying cries cry"
tokenization = nltk.word_tokenize(text)
for w in tokenization:
  print("Lemma for {} is {}".format(w, wordnet_lemmatizer.lemmatize(w)))
# Out:
# Lemma for studies is study
# Lemma for studying is studying
# Lemma for cries is cry
# Lemma for cry is cry

# %% [markdown]
# Apply POS Tagging to text

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
from nltk.tokenize import word_tokenize
data="The pink sweater fit her perfectly"
words=word_tokenize(data)
for word in words:
  print(nltk.pos_tag([word]))
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [('The', 'DT')]
# [('pink', 'NN')]
# [('sweater', 'NN')]
# [('fit', 'NN')]
# [('her', 'PRP$')]
# [('perfectly', 'RB')]

# %% [markdown]
# # Part 2

# %% [markdown]
# Import the necessary libraries.

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# Initialize the Documents.

# %%
documentA = 'Jupiter is the largest Planet'
documentB = 'Mars is the fourth planet from the Sun'

# %% [markdown]
# Create BagofWords (BoW) for Document A and B.

# %%
bagOfWordsA = documentA.split(' ')

# %%
bagOfWordsA
# Out:
# ['Jupiter', 'is', 'the', 'largest', 'Planet']

# %%
bagOfWordsB = documentB.split(' ')

# %%
bagOfWordsB
# Out:
# ['Mars', 'is', 'the', 'fourth', 'planet', 'from', 'the', 'Sun']

# %% [markdown]
# Create Collection of Unique words from Document A and B.

# %%
uniqueWords = set(bagOfWordsA).union(set(bagOfWordsB))

# %%
uniqueWords
# Out:
# {'Jupiter',
#  'Mars',
#  'Planet',
#  'Sun',
#  'fourth',
#  'from',
#  'is',
#  'largest',
#  'planet',
#  'the'}

# %% [markdown]
# Create a dictionary of words and their occurrence for each document in the
# corpus

# %%
numOfWordsA = dict.fromkeys(uniqueWords, 0)
for word in bagOfWordsA:
  numOfWordsA[word] += 1
  numOfWordsB = dict.fromkeys(uniqueWords, 0)
for word in bagOfWordsB:
  numOfWordsB[word] += 1

# %%
numOfWordsA
# Out:
# {'planet': 0,
#  'Sun': 0,
#  'the': 1,
#  'Planet': 1,
#  'is': 1,
#  'Mars': 0,
#  'fourth': 0,
#  'largest': 1,
#  'from': 0,
#  'Jupiter': 1}

# %%
numOfWordsB
# Out:
# {'planet': 1,
#  'Sun': 1,
#  'the': 2,
#  'Planet': 0,
#  'is': 1,
#  'Mars': 1,
#  'fourth': 1,
#  'largest': 0,
#  'from': 1,
#  'Jupiter': 0}

# %% [markdown]
# Compute the term frequency for each of our documents.

# %%
def computeTF(wordDict, bagOfWords):
  tfDict = {}
  bagOfWordsCount = len(bagOfWords)
  for word, count in wordDict.items():
    tfDict[word] = count / float(bagOfWordsCount)
  return tfDict

# %%
tfA = computeTF(numOfWordsA, bagOfWordsA)

# %%
tfA
# Out:
# {'planet': 0.0,
#  'Sun': 0.0,
#  'the': 0.2,
#  'Planet': 0.2,
#  'is': 0.2,
#  'Mars': 0.0,
#  'fourth': 0.0,
#  'largest': 0.2,
#  'from': 0.0,
#  'Jupiter': 0.2}

# %%
tfB = computeTF(numOfWordsB, bagOfWordsB)

# %%
tfB
# Out:
# {'planet': 0.125,
#  'Sun': 0.125,
#  'the': 0.25,
#  'Planet': 0.0,
#  'is': 0.125,
#  'Mars': 0.125,
#  'fourth': 0.125,
#  'largest': 0.0,
#  'from': 0.125,
#  'Jupiter': 0.0}

# %% [markdown]
# Compute the term Inverse Document Frequency.

# %%
import math
def computeIDF(documents):
  N = len(documents)
  idfDict = dict.fromkeys(documents[0].keys(), 0)
  for document in documents:
    for word, val in document.items():
      if val > 0:
        idfDict[word] += 1
  for word, val in idfDict.items():
    idfDict[word] = math.log(N / float(val))
  return idfDict

# %%
idfs = computeIDF([numOfWordsA, numOfWordsB])
idfs
# Out:
# {'planet': 0.6931471805599453,
#  'Sun': 0.6931471805599453,
#  'the': 0.0,
#  'Planet': 0.6931471805599453,
#  'is': 0.0,
#  'Mars': 0.6931471805599453,
#  'fourth': 0.6931471805599453,
#  'largest': 0.6931471805599453,
#  'from': 0.6931471805599453,
#  'Jupiter': 0.6931471805599453}

# %% [markdown]
# Compute the term TF/IDF for all words.

# %%
def computeTFIDF(tfBagOfWords, idfs):
  tfidf = {}
  for word, val in tfBagOfWords.items():
    tfidf[word] = val * idfs[word]
  return tfidf

# %%
tfidfA = computeTFIDF(tfA, idfs)
tfidfA
# Out:
# {'planet': 0.0,
#  'Sun': 0.0,
#  'the': 0.0,
#  'Planet': 0.13862943611198905,
#  'is': 0.0,
#  'Mars': 0.0,
#  'fourth': 0.0,
#  'largest': 0.13862943611198905,
#  'from': 0.0,
#  'Jupiter': 0.13862943611198905}

# %%
tfidfB = computeTFIDF(tfB, idfs)
tfidfB
# Out:
# {'planet': 0.08664339756999316,
#  'Sun': 0.08664339756999316,
#  'the': 0.0,
#  'Planet': 0.0,
#  'is': 0.0,
#  'Mars': 0.08664339756999316,
#  'fourth': 0.08664339756999316,
#  'largest': 0.0,
#  'from': 0.08664339756999316,
#  'Jupiter': 0.0}

# %%
df = pd.DataFrame([tfidfA, tfidfB])
df
# Out:
#      planet       Sun  the    Planet   is      Mars    fourth   largest  \
# 0  0.000000  0.000000  0.0  0.138629  0.0  0.000000  0.000000  0.138629
# 1  0.086643  0.086643  0.0  0.000000  0.0  0.086643  0.086643  0.000000
#
#        from   Jupiter
# 0  0.000000  0.138629
# 1  0.086643  0.000000

# %% [markdown]
# Conclusion:<br>
# In this way we have done text data analysis using TF IDF algorithm
